# %% [markdown]
# <a href="https://colab.research.google.com/github/RishithaKunchala/CP/blob/main/Week_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fibonacci(n, dp):
    if n <= 1:
        return n

    if dp[n] != -1:
        return dp[n]

    dp[n] = fibonacci(n - 1, dp) + fibonacci(n - 2, dp)
    return dp[n]

n = int(input())
dp = [-1] * (n + 1)

print(fibonacci(n, dp))
# Out:
# 10
# 55

# %%
def subset_sum(arr, n, target):
    if target == 0:
        return True
    if n == 0 or target < 0:
        return False

    return (subset_sum(arr, n - 1, target - arr[n - 1]) or
            subset_sum(arr, n - 1, target))


# Input
n = int(input())
arr = list(map(int, input().split()))
target = int(input())

# Output
print(subset_sum(arr, n, target))
# Out:
# 5
# 3 34 4 12 5
# 9
# True
